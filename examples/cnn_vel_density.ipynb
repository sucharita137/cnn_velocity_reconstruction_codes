# %%
import sys
import os

# %%
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from kszcnn.cnn_vel_density import train_and_eval
# Out:
# Device: cuda

# %%
results = train_and_eval(make_plots=True)
# Out:
# Grid shapes (train, test): (128, 128, 128) (128, 128, 128)
# Building multi-scale overdensity channels...
# Loaded halos (train, test): 20817 21205
# Selected 547 halos (mass_cut=100000000000.0, cap=5000).
# Selected 569 halos (mass_cut=100000000000.0, cap=5000).
# Computing v_lin baseline (on CNN test halos)...
# ρ (v_lin baseline, mass-cut halos) = 0.8551
# Train vz mean/std: -1.0862698554992676 105.11466979980469
# Epoch   1/60 | TrainLoss=4.3392e-01  ValLoss=8.2542e-01  ρ_val=0.723  (11.3s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch   2/60 | TrainLoss=3.0744e-01  ValLoss=5.0340e-01  ρ_val=0.752  (10.9s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch   3/60 | TrainLoss=2.5897e-01  ValLoss=3.8422e-01  ρ_val=0.801  (11.0s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch   4/60 | TrainLoss=2.4276e-01  ValLoss=4.2884e-01  ρ_val=0.784  (11.0s)
# Epoch   5/60 | TrainLoss=2.4743e-01  ValLoss=3.7781e-01  ρ_val=0.787  (11.1s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch   6/60 | TrainLoss=2.2802e-01  ValLoss=4.9620e-01  ρ_val=0.810  (11.2s)
# Epoch   7/60 | TrainLoss=2.4849e-01  ValLoss=3.9662e-01  ρ_val=0.805  (11.2s)
# Epoch   8/60 | TrainLoss=2.3251e-01  ValLoss=3.6792e-01  ρ_val=0.797  (11.2s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch   9/60 | TrainLoss=2.0507e-01  ValLoss=3.9901e-01  ρ_val=0.829  (11.3s)
# Epoch  10/60 | TrainLoss=2.0868e-01  ValLoss=3.7623e-01  ρ_val=0.815  (11.4s)
# Epoch  11/60 | TrainLoss=2.1898e-01  ValLoss=3.3140e-01  ρ_val=0.828  (11.4s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch  12/60 | TrainLoss=2.1094e-01  ValLoss=3.3263e-01  ρ_val=0.831  (11.4s)
# Epoch  13/60 | TrainLoss=2.0005e-01  ValLoss=3.5552e-01  ρ_val=0.826  (11.4s)
# Epoch  14/60 | TrainLoss=1.9967e-01  ValLoss=3.1364e-01  ρ_val=0.831  (11.4s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch  15/60 | TrainLoss=1.9352e-01  ValLoss=2.9444e-01  ρ_val=0.837  (11.4s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch  16/60 | TrainLoss=1.8836e-01  ValLoss=2.8587e-01  ρ_val=0.847  (11.4s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch  17/60 | TrainLoss=1.8082e-01  ValLoss=2.9748e-01  ρ_val=0.856  (11.4s)
# Epoch  18/60 | TrainLoss=1.9464e-01  ValLoss=3.1963e-01  ρ_val=0.840  (11.4s)
# Epoch  19/60 | TrainLoss=1.8883e-01  ValLoss=2.9783e-01  ρ_val=0.850  (11.4s)
# Epoch  20/60 | TrainLoss=1.8053e-01  ValLoss=2.9123e-01  ρ_val=0.851  (11.4s)
# Epoch  21/60 | TrainLoss=1.9468e-01  ValLoss=3.0835e-01  ρ_val=0.847  (11.4s)
# Epoch  22/60 | TrainLoss=1.8820e-01  ValLoss=2.7358e-01  ρ_val=0.849  (11.4s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch  23/60 | TrainLoss=1.7433e-01  ValLoss=3.3201e-01  ρ_val=0.832  (11.4s)
# Epoch  24/60 | TrainLoss=1.6915e-01  ValLoss=2.9080e-01  ρ_val=0.859  (11.4s)
# Epoch  25/60 | TrainLoss=1.6736e-01  ValLoss=2.8803e-01  ρ_val=0.861  (11.4s)
# Epoch  26/60 | TrainLoss=1.7937e-01  ValLoss=3.2909e-01  ρ_val=0.828  (11.4s)
# Epoch  27/60 | TrainLoss=1.7360e-01  ValLoss=2.8853e-01  ρ_val=0.853  (11.4s)
# Epoch  28/60 | TrainLoss=1.7707e-01  ValLoss=2.7924e-01  ρ_val=0.864  (11.4s)
# Epoch  29/60 | TrainLoss=1.8177e-01  ValLoss=3.4262e-01  ρ_val=0.847  (11.4s)
# Epoch  30/60 | TrainLoss=1.6913e-01  ValLoss=2.8933e-01  ρ_val=0.852  (11.4s)
# Epoch  31/60 | TrainLoss=1.6239e-01  ValLoss=3.0900e-01  ρ_val=0.857  (11.4s)
# Epoch  32/60 | TrainLoss=1.6469e-01  ValLoss=2.5557e-01  ρ_val=0.860  (11.4s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch  33/60 | TrainLoss=1.4874e-01  ValLoss=2.5726e-01  ρ_val=0.860  (11.4s)
# Epoch  34/60 | TrainLoss=1.5224e-01  ValLoss=2.6686e-01  ρ_val=0.859  (11.4s)
# Epoch  35/60 | TrainLoss=1.6092e-01  ValLoss=2.9942e-01  ρ_val=0.852  (11.4s)
# Epoch  36/60 | TrainLoss=1.6253e-01  ValLoss=2.4189e-01  ρ_val=0.866  (11.4s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch  37/60 | TrainLoss=1.5658e-01  ValLoss=2.5302e-01  ρ_val=0.866  (11.4s)
# Epoch  38/60 | TrainLoss=1.5263e-01  ValLoss=2.6222e-01  ρ_val=0.856  (11.4s)
# Epoch  39/60 | TrainLoss=1.4562e-01  ValLoss=2.4431e-01  ρ_val=0.869  (11.4s)
# Epoch  40/60 | TrainLoss=1.4159e-01  ValLoss=2.5800e-01  ρ_val=0.862  (11.4s)
# Epoch  41/60 | TrainLoss=1.5235e-01  ValLoss=2.4571e-01  ρ_val=0.866  (11.4s)
# Epoch  42/60 | TrainLoss=1.5130e-01  ValLoss=3.1847e-01  ρ_val=0.852  (11.4s)
# Epoch  43/60 | TrainLoss=1.5483e-01  ValLoss=2.4771e-01  ρ_val=0.866  (11.4s)
# Epoch  44/60 | TrainLoss=1.4110e-01  ValLoss=2.7499e-01  ρ_val=0.862  (11.4s)
# Epoch  45/60 | TrainLoss=1.4213e-01  ValLoss=2.5825e-01  ρ_val=0.863  (11.4s)
# Epoch  46/60 | TrainLoss=1.4217e-01  ValLoss=2.4365e-01  ρ_val=0.868  (11.4s)
# Epoch  47/60 | TrainLoss=1.4512e-01  ValLoss=2.3607e-01  ρ_val=0.871  (11.4s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch  48/60 | TrainLoss=1.4256e-01  ValLoss=2.3837e-01  ρ_val=0.870  (11.4s)
# Epoch  49/60 | TrainLoss=1.3388e-01  ValLoss=2.5673e-01  ρ_val=0.869  (11.4s)
# Epoch  50/60 | TrainLoss=1.4201e-01  ValLoss=2.4735e-01  ρ_val=0.865  (11.4s)
# Epoch  51/60 | TrainLoss=1.4436e-01  ValLoss=2.4340e-01  ρ_val=0.866  (11.4s)
# Epoch  52/60 | TrainLoss=1.4555e-01  ValLoss=2.6308e-01  ρ_val=0.868  (11.4s)
# Epoch  53/60 | TrainLoss=1.3216e-01  ValLoss=2.4298e-01  ρ_val=0.867  (11.4s)
# Epoch  54/60 | TrainLoss=1.3011e-01  ValLoss=2.5693e-01  ρ_val=0.862  (11.4s)
# Epoch  55/60 | TrainLoss=1.2951e-01  ValLoss=2.5226e-01  ρ_val=0.866  (11.4s)
# Epoch  56/60 | TrainLoss=1.3482e-01  ValLoss=2.3787e-01  ρ_val=0.870  (11.4s)
# Epoch  57/60 | TrainLoss=1.3342e-01  ValLoss=2.5648e-01  ρ_val=0.869  (11.4s)
# Epoch  58/60 | TrainLoss=1.3498e-01  ValLoss=2.5486e-01  ρ_val=0.867  (11.4s)
# Epoch  59/60 | TrainLoss=1.2927e-01  ValLoss=2.3839e-01  ρ_val=0.872  (11.4s)
# Epoch  60/60 | TrainLoss=1.2871e-01  ValLoss=2.3642e-01  ρ_val=0.870  (11.4s)
# Training finished. Best epoch 47, best val loss 2.3607e-01
# ----- Test metrics (configured test set) -----
# Raw CNN:   N=569, ρ=0.8542, bias=3.206, rmse=50.441
# Baseline v_lin ρ (interpolated) = 0.8551
# Saved: checkpoints_no_vlin_improved_v2/vlin_vs_cnn_density_only_testReal14.png

# %%
print("CNN rho:", results["rho_cnn"])
print("v_lin rho:", results["rho_vlin"])
# Out:
# CNN rho: 0.85424566
# v_lin rho: 0.8551195
