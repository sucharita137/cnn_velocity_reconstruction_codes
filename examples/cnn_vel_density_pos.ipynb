# %%
import sys
import os

# %%
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from kszcnn.cnn_vel_density_pos import train_and_eval
# Out:
# Device: cuda

# %%
results = train_and_eval(make_plots=True)
# Out:
# Grid shapes (train, test): (128, 128, 128) (128, 128, 128)
# Building multi-scale overdensity channels...
# Loaded halos (train, test): 20817 21205
# Selected 547 halos (mass_cut=100000000000.0, cap=5000).
# Selected 569 halos (mass_cut=100000000000.0, cap=5000).
# Computing v_lin baseline (on CNN test halos)...
# ρ (v_lin baseline, mass-cut halos) = 0.8551
# Train vz mean/std: -1.0862698554992676 105.11466979980469
# Epoch   1/60 | TrainLoss=5.7755e-01  ValLoss=1.2627e+00  ρ_val=0.563  (11.8s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch   2/60 | TrainLoss=5.1250e-01  ValLoss=8.4920e-01  ρ_val=0.430  (11.5s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch   3/60 | TrainLoss=3.3284e-01  ValLoss=4.2335e-01  ρ_val=0.785  (11.5s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch   4/60 | TrainLoss=2.6538e-01  ValLoss=5.1680e-01  ρ_val=0.812  (11.6s)
# Epoch   5/60 | TrainLoss=2.7057e-01  ValLoss=3.8028e-01  ρ_val=0.815  (11.7s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch   6/60 | TrainLoss=2.2114e-01  ValLoss=3.5230e-01  ρ_val=0.824  (11.7s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch   7/60 | TrainLoss=2.2735e-01  ValLoss=4.3709e-01  ρ_val=0.850  (11.8s)
# Epoch   8/60 | TrainLoss=2.3673e-01  ValLoss=2.7619e-01  ρ_val=0.858  (11.8s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch   9/60 | TrainLoss=1.9927e-01  ValLoss=3.2796e-01  ρ_val=0.867  (12.0s)
# Epoch  10/60 | TrainLoss=2.2608e-01  ValLoss=2.5668e-01  ρ_val=0.870  (12.0s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch  11/60 | TrainLoss=2.2856e-01  ValLoss=2.6545e-01  ρ_val=0.867  (12.0s)
# Epoch  12/60 | TrainLoss=1.9790e-01  ValLoss=2.4216e-01  ρ_val=0.874  (12.0s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch  13/60 | TrainLoss=1.8962e-01  ValLoss=2.7463e-01  ρ_val=0.875  (12.0s)
# Epoch  14/60 | TrainLoss=1.9540e-01  ValLoss=3.0390e-01  ρ_val=0.859  (12.0s)
# Epoch  15/60 | TrainLoss=1.8499e-01  ValLoss=3.3858e-01  ρ_val=0.880  (12.0s)
# Epoch  16/60 | TrainLoss=1.8497e-01  ValLoss=3.0184e-01  ρ_val=0.866  (12.0s)
# Epoch  17/60 | TrainLoss=1.8996e-01  ValLoss=2.5217e-01  ρ_val=0.859  (12.0s)
# Epoch  18/60 | TrainLoss=1.9776e-01  ValLoss=2.4185e-01  ρ_val=0.874  (12.0s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch  19/60 | TrainLoss=1.9293e-01  ValLoss=2.9626e-01  ρ_val=0.880  (12.0s)
# Epoch  20/60 | TrainLoss=1.9769e-01  ValLoss=2.5384e-01  ρ_val=0.885  (12.0s)
# Epoch  21/60 | TrainLoss=1.7398e-01  ValLoss=2.7530e-01  ρ_val=0.853  (12.0s)
# Epoch  22/60 | TrainLoss=1.6780e-01  ValLoss=2.4919e-01  ρ_val=0.878  (12.0s)
# Epoch  23/60 | TrainLoss=1.6603e-01  ValLoss=2.7060e-01  ρ_val=0.887  (12.0s)
# Epoch  24/60 | TrainLoss=1.6776e-01  ValLoss=2.3568e-01  ρ_val=0.878  (12.0s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch  25/60 | TrainLoss=1.6232e-01  ValLoss=3.6259e-01  ρ_val=0.825  (12.1s)
# Epoch  26/60 | TrainLoss=1.7092e-01  ValLoss=2.3336e-01  ρ_val=0.873  (12.2s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch  27/60 | TrainLoss=1.6571e-01  ValLoss=2.3223e-01  ρ_val=0.894  (12.1s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch  28/60 | TrainLoss=1.6786e-01  ValLoss=2.1866e-01  ρ_val=0.886  (12.0s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch  29/60 | TrainLoss=1.5762e-01  ValLoss=2.2023e-01  ρ_val=0.883  (12.0s)
# Epoch  30/60 | TrainLoss=1.6658e-01  ValLoss=2.2943e-01  ρ_val=0.890  (12.0s)
# Epoch  31/60 | TrainLoss=1.7537e-01  ValLoss=2.2233e-01  ρ_val=0.882  (12.1s)
# Epoch  32/60 | TrainLoss=1.6341e-01  ValLoss=2.2794e-01  ρ_val=0.888  (12.0s)
# Epoch  33/60 | TrainLoss=1.5796e-01  ValLoss=2.5772e-01  ρ_val=0.895  (12.0s)
# Epoch  34/60 | TrainLoss=1.6685e-01  ValLoss=2.3333e-01  ρ_val=0.871  (12.0s)
# Epoch  35/60 | TrainLoss=1.7420e-01  ValLoss=3.3270e-01  ρ_val=0.881  (12.0s)
# Epoch  36/60 | TrainLoss=1.6608e-01  ValLoss=2.0787e-01  ρ_val=0.886  (12.0s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch  37/60 | TrainLoss=1.5239e-01  ValLoss=2.0443e-01  ρ_val=0.889  (12.0s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch  38/60 | TrainLoss=1.4390e-01  ValLoss=2.0012e-01  ρ_val=0.891  (12.0s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch  39/60 | TrainLoss=1.4484e-01  ValLoss=2.0066e-01  ρ_val=0.895  (12.1s)
# Epoch  40/60 | TrainLoss=1.4887e-01  ValLoss=2.1652e-01  ρ_val=0.892  (12.1s)
# Epoch  41/60 | TrainLoss=1.4327e-01  ValLoss=2.0982e-01  ρ_val=0.893  (12.0s)
# Epoch  42/60 | TrainLoss=1.4053e-01  ValLoss=1.9851e-01  ρ_val=0.892  (12.0s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch  43/60 | TrainLoss=1.4104e-01  ValLoss=1.9153e-01  ρ_val=0.896  (12.0s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch  44/60 | TrainLoss=1.4362e-01  ValLoss=2.3298e-01  ρ_val=0.885  (12.0s)
# Epoch  45/60 | TrainLoss=1.4147e-01  ValLoss=2.0288e-01  ρ_val=0.891  (12.0s)
# Epoch  46/60 | TrainLoss=1.4097e-01  ValLoss=2.4541e-01  ρ_val=0.893  (12.0s)
# Epoch  47/60 | TrainLoss=1.3578e-01  ValLoss=2.0037e-01  ρ_val=0.891  (12.0s)
# Epoch  48/60 | TrainLoss=1.3566e-01  ValLoss=1.9878e-01  ρ_val=0.897  (12.0s)
# Epoch  49/60 | TrainLoss=1.4130e-01  ValLoss=2.0472e-01  ρ_val=0.890  (12.0s)
# Epoch  50/60 | TrainLoss=1.3691e-01  ValLoss=2.1318e-01  ρ_val=0.890  (12.0s)
# Epoch  51/60 | TrainLoss=1.2965e-01  ValLoss=2.0835e-01  ρ_val=0.897  (12.1s)
# Epoch  52/60 | TrainLoss=1.3531e-01  ValLoss=2.0377e-01  ρ_val=0.894  (12.0s)
# Epoch  53/60 | TrainLoss=1.2721e-01  ValLoss=1.9342e-01  ρ_val=0.895  (12.2s)
# Epoch  54/60 | TrainLoss=1.3751e-01  ValLoss=2.0696e-01  ρ_val=0.889  (12.0s)
# Epoch  55/60 | TrainLoss=1.2552e-01  ValLoss=2.0318e-01  ρ_val=0.891  (12.0s)
# Epoch  56/60 | TrainLoss=1.3557e-01  ValLoss=1.9009e-01  ρ_val=0.899  (12.0s)
#   → Saved new best checkpoint: checkpoints_no_vlin_improved_v2/cnn_best_density_only.pth
# Epoch  57/60 | TrainLoss=1.3394e-01  ValLoss=1.9981e-01  ρ_val=0.892  (12.0s)
# Epoch  58/60 | TrainLoss=1.2936e-01  ValLoss=2.0076e-01  ρ_val=0.891  (12.0s)
# Epoch  59/60 | TrainLoss=1.2647e-01  ValLoss=1.9586e-01  ρ_val=0.893  (12.0s)
# Epoch  60/60 | TrainLoss=1.2744e-01  ValLoss=2.0565e-01  ρ_val=0.891  (12.0s)
# Training finished. Best epoch 56, best val loss 1.9009e-01
# ----- Test metrics (configured test set) -----
# Raw CNN:   N=569, ρ=0.8700, bias=5.396, rmse=48.252
# Baseline v_lin ρ (interpolated) = 0.8551
# Saved: checkpoints_no_vlin_improved_v2/vlin_vs_cnn_density_pos_testReal14.png

# %%
print("CNN rho:", results["rho_cnn"])
print("v_lin rho:", results["rho_vlin"])
# Out:
# CNN rho: 0.86996627
# v_lin rho: 0.8551195
